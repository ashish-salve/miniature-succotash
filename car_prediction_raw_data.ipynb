# %% [markdown]
# ### Import dataset

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('olx_cars_18sept_2.csv',index_col=None)
df1
# Out:
#                                Model Fuel Type      Mileage  Owner  \
# 0             Tata Indigo Ecs (2010)    PETROL   65000.0 KM    2nd
# 1   Maruti Suzuki Swift Dzire (2018)    DIESEL   32000.0 KM    1st
# 2        Maruti Suzuki Ertiga (2018)    DIESEL   48000.0 KM    1st
# 3                 Hyundai I10 (2013)    PETROL   68000.0 KM    2nd
# 4                   Tata Nano (2015)    PETROL   22000.0 KM    1st
# 5      Maruti Suzuki Alto K10 (2018)    PETROL      8697 KM  First
# 6   Maruti Suzuki Swift Dzire (2014)    DIESEL   85080.0 KM    1st
# 7            Mahindra Tuv 300 (2016)    DIESEL   51000.0 KM    1st
# 8       Maruti Suzuki Celerio (2017)    PETROL   41000.0 KM    1st
# 9      Maruti Suzuki Alto 800 (2015)    PETROL   46000.0 KM    2nd
# 10            Tata Sumo Victa (2012)    DIESEL   127,418 KM    2nd
# 11              Ford Ecosport (2017)    DIESEL   57000.0 KM    1st
# 12            Mahindra Xuv500 (2017)    DIESEL   22000.0 KM    1st
# ...

# %%
df2 = pd.read_csv('olx_cars_18sept_3.csv',index_col=None)
df2
# Out:
#                                    Model      Fuel Type     Mileage Owner  \
# 0                          Bmw X1 (2018)         DIESEL  52000.0 KM   1st
# 1                 Mahindra Xuv500 (2014)         DIESEL  60000.0 KM   2nd
# 2                  Chevrolet Sail (2013)         DIESEL  79000.0 KM   1st
# 3                     Hyundai I10 (2015)  CNG & HYBRIDS  76000.0 KM   1st
# 4          Maruti Suzuki Alto 800 (2015)         PETROL  20000.0 KM   1st
# 5                   Ford Ecosport (2015)         DIESEL  63000.0 KM   1st
# 6   Land Rover Range Rover Evoque (2017)         DIESEL  29500.0 KM   1st
# 7                 Volkswagen Polo (2010)         PETROL  57000.0 KM   1st
# 8                      Honda City (2011)         PETROL   52,000 KM   1st
# 9           Maruti Suzuki Celerio (2017)         PETROL  41000.0 KM   1st
# 10                 Renault Duster (2012)         DIESEL  65000.0 KM   2nd
#
#                   Location        Price
# ...

# %%
df3 = pd.read_csv('olx_cars_18sept_4.csv',index_col=None)
df3
# Out:
#                                    Model      Fuel Type      Mileage Owner  \
# 0                Volkswagen Vento (2012)         DIESEL   55000.0 KM   1st
# 1                   Ford Ecosport (2014)         DIESEL   54000.0 KM   1st
# 2                     Tata Safari (2012)         DIESEL   75000.0 KM   1st
# 3                 Mahindra Xuv500 (2012)         DIESEL   65000.0 KM   2nd
# 4              Tata Safari Storme (2013)         DIESEL   65000.0 KM   1st
# 5   Land Rover Range Rover Evoque (2017)         DIESEL   22000.0 KM   1st
# 6             Hyundai Santro Xing (2014)         PETROL   39000.0 KM   1st
# 7               Toyota Etios Liva (2015)         PETROL   57585.0 KM   1st
# 8                         Audi A4 (2013)         DIESEL   94000.0 KM   2nd
# 9                     Hyundai I20 (2013)         DIESEL   74000.0 KM   1st
# 10                    Hyundai I20 (2013)         PETROL   57112.0 KM   1st
# ...

# %%
df4 = pd.read_csv('olx_cars_18sept_5.csv',index_col=None)
df4
# Out:
#                                Model      Fuel Type     Mileage Owner  \
# 0             Mahindra Bolero (2013)         DIESEL  65000.0 KM   1st
# 1              Nissan Terrano (2015)         DIESEL  89000.0 KM   1st
# 2             Volkswagen Polo (2015)         DIESEL  59251.0 KM    --
# 3                Toyota Yaris (2018)         PETROL  21633.0 KM    --
# 4        Maruti Suzuki Ertiga (2020)         PETROL   5000.0 KM   1st
# 5                  Honda City (2009)         PETROL  52655.0 KM   1st
# 6              Renault Duster (2016)         DIESEL  57000.0 KM   1st
# 7              Renault Duster (2015)         DIESEL  50000.0 KM   1st
# 8        Toyota Corolla Altis (2015)         DIESEL  28000.0 KM   1st
# 9        Maruti Suzuki Ertiga (2014)         DIESEL  55588.0 KM   1st
# 10              Ford Ecosport (2018)         PETROL  26000.0 KM   1st
# 11          Hyundai Grand I10 (2015)         PETROL  26000.0 KM   1st
# ...

# %%
df5 = pd.read_csv('olx_cars_18sept_6.csv',index_col=None)
df5
# Out:
#                                  Model      Fuel Type      Mileage Owner  \
# 0   Maruti Suzuki Vitara Brezza (2016)         DIESEL   62704.0 KM    --
# 1   Maruti Suzuki Vitara Brezza (2017)         DIESEL   69000.0 KM   1st
# 2           Maruti Suzuki Swift (2015)         DIESEL   26000.0 KM   2nd
# 3                 Mahindra Thar (2019)         DIESEL   19000.0 KM   1st
# 4               Volkswagen Polo (2017)         PETROL   51000.0 KM   1st
# 5          Toyota Innova Crysta (2016)         DIESEL  112000.0 KM   1st
# 6                 Hyundai Creta (2015)         DIESEL   53000.0 KM   1st
# 7            Tata Safari Storme (2012)         DIESEL   80000.0 KM   1st
# 8          Toyota Corolla Altis (2018)         PETROL   19000.0 KM   1st
# 9                 Toyota Innova (2014)         DIESEL   72000.0 KM   2nd
# 10                  Hyundai I20 (2011)         PETROL   48000.0 KM   1st
# 11  Maruti Suzuki Vitara Brezza (2018)         DIESEL   29000.0 KM   1st
# ...

# %%
df6 = pd.read_csv('olx_cars_18sept_7.csv',index_col=None)
df6
# Out:
#                               Model Fuel Type     Mileage Owner  \
# 0                Hyundai I20 (2010)    PETROL  75000.0 KM   1st
# 1  Maruti Suzuki Swift Dzire (2016)    PETROL  32000.0 KM   1st
# 2          Hyundai Grand I10 (2019)    PETROL  30000.0 KM   2nd
# 3                 Honda Brio (2012)    PETROL  41000.0 KM   1st
# 4       Maruti Suzuki Ertiga (2016)    PETROL  65000.0 KM   1st
# 5               Bmw 5 Series (2011)    DIESEL  80000.0 KM   1st
#
#              Location        Price
# 0  Kirti Nagar, Delhi   ₹ 2,21,000
# 1     Badarpur, Delhi   ₹ 4,90,000
# 2  Kirti Nagar, Delhi   ₹ 4,90,000
# 3  Kirti Nagar, Delhi   ₹ 2,72,000
# 4  Lalita Park, Delhi   ₹ 6,10,000
# 5     Jangpura, Delhi  ₹ 10,99,999

# %%
df7 = pd.read_csv('olx_cars_18sept_8.csv',index_col=None)
df7
# Out:
#                                Model Fuel Type     Mileage  Owner  \
# 0        Maruti Suzuki Ertiga (2017)    DIESEL    24000 KM  First
# 1            Ford Figo Aspire (2016)    DIESEL  58000.0 KM    1st
# 2   Maruti Suzuki Swift Dzire (2012)    DIESEL  69000.0 KM     --
# 3              Chevrolet Beat (2013)    DIESEL  61000.0 KM    1st
# 4       Mercedes-Benz E-Class (2009)    PETROL  65000.0 KM    3rd
# ..                               ...       ...         ...    ...
# 74            Toyota Fortuner (2011)    DIESEL  82000.0 KM    1st
# 75               Bmw 5 Series (2014)    DIESEL  50000.0 KM    2nd
# 76                    Audi Q7 (2011)    DIESEL  88000.0 KM    2nd
# 77       Toyota Corolla Altis (2009)    PETROL  80000.0 KM    3rd
# 78             Hyundai Santro (2008)    PETROL  55000.0 KM    1st
#
#                  Location        Price
# 0   Lajpat Nagar 1, Delhi   ₹ 7,50,000
# 1   Lajpat Nagar 2, Delhi   ₹ 3,90,000
# 2       Karol Bagh, Delhi   ₹ 2,80,000
# ...

# %%
df8 = pd.read_csv('olx_cars_18sept_9.csv',index_col=None)
df8
# Out:
#                                  Model      Fuel Type     Mileage Owner  \
# 0              Mahindra Scorpio (2012)         DIESEL  60000.0 KM   4th
# 1                       Audi A6 (2013)         DIESEL  59800.0 KM   3rd
# 2             Mercedes-Benz Cla (2019)         DIESEL   4000.0 KM   1st
# 3               Volkswagen Polo (2016)         DIESEL  63000.0 KM   1st
# 4   Maruti Suzuki Vitara Brezza (2017)         DIESEL  50000.0 KM   1st
# ..                                 ...            ...         ...   ...
# 73    Maruti Suzuki Wagon R 1.0 (2012)  CNG & HYBRIDS  52000.0 KM   1st
# 74             Hyundai Santa Fe (2015)         DIESEL  85000.0 KM   1st
# 75              Mahindra Xuv500 (2014)         DIESEL  65000.0 KM   1st
# 76        Hyundai Fluidic Verna (2017)         DIESEL  43221.0 KM   1st
# 77                Ford Ecosport (2013)         DIESEL  62000.0 KM   1st
#
#                        Location        Price
# 0                    ITO, Delhi   ₹ 3,25,000
# ...

# %%
df9 = pd.read_csv('olx_cars_19sept_1.csv',index_col=None)
df9
# Out:
#                           Model Fuel Type     Mileage Owner  \
# 0         Renault Duster (2017)    DIESEL  52000.0 KM   1st
# 1                Audi Q3 (2017)    PETROL  40000.0 KM   1st
# 2        Mahindra Xuv300 (2019)    DIESEL  22000.0 KM   1st
# 3        Mahindra Xuv500 (2012)    DIESEL  72000.0 KM   1st
# 4        Mahindra Xuv500 (2013)    DIESEL  65000.0 KM   1st
# ..                          ...       ...         ...   ...
# 106         Bmw 5 Series (2013)    DIESEL  53000.0 KM   1st
# 107    Fiat Grande Punto (2015)    DIESEL  78000.0 KM   1st
# 108           Honda Br-V (2016)    PETROL   64,000 KM   1st
# 109  Maruti Suzuki Swift (2009)    PETROL  63000.0 KM   1st
# 110   Maruti Suzuki Ritz (2013)    PETROL  85000.0 KM    --
#
#                         Location        Price
# 0            Geeta Colony, Delhi   ₹ 6,90,000
# 1             Ashok Vihar, Delhi  ₹ 26,00,000
# 2    Netaji Subhash Place, Delhi   ₹ 9,25,000
# 3       Punjabi Bagh West, Delhi   ₹ 4,65,000
# ...

# %%
df10 = pd.read_csv('olx_cars_19sept_2.csv',index_col=None)
df10
# Out:
#                                  Model      Fuel Type     Mileage Owner  \
# 0               Toyota Fortuner (2015)         DIESEL  60000.0 KM   1st
# 1                Ford Endeavour (2018)         DIESEL  27000.0 KM   1st
# 2                   Hyundai I10 (2008)         PETROL  57000.0 KM    --
# 3     Mercedes-Benz New C-Class (2020)         DIESEL   6000.0 KM   1st
# 4                  Toyota Etios (2011)         PETROL  52000.0 KM   2nd
# 5               Toyota Fortuner (2019)         DIESEL  37450.0 KM   1st
# 6                 Honda City Zx (2020)         PETROL  20000.0 KM   1st
# 7            Hyundai Grand I 10 (2015)         DIESEL  50000.0 KM    --
# 8                  Jeep Compass (2018)         DIESEL  125,000 KM   1st
# 9             Maruti Suzuki 800 (2009)  CNG & HYBRIDS   52,000 KM   2nd
# 10                Hyundai Creta (2018)         DIESEL  84585.0 KM   1st
# 11                   Tata Manza (2010)         DIESEL   58,000 KM    --
# ...

# %%
df11 = pd.read_csv('olx_cars_19sept_3.csv',index_col=None)
df11
# Out:
#                                     Model Fuel Type      Mileage Owner  \
# 0    Land Rover Range Rover Evoque (2015)    DIESEL   41000.0 KM   2nd
# 1                 Mahindra Scorpio (2012)    DIESEL   80000.0 KM   1st
# 2                  Mahindra Bolero (2016)    DIESEL   56589.0 KM   1st
# 3                      Honda Amaze (2014)    DIESEL   51000.0 KM   1st
# 4            Hyundai Fluidic Verna (2014)    DIESEL   91000.0 KM   1st
# ..                                    ...       ...          ...   ...
# 115                  Hyundai Creta (2018)    DIESEL   52000.0 KM   1st
# 116                  Hyundai Creta (2020)    PETROL    5000.0 KM   1st
# 117                    Hyundai I20 (2011)    PETROL   40000.0 KM   1st
# 118                   Bmw 3 Series (2014)    DIESEL  102720.0 KM   2nd
# 119                  Hyundai Venue (2020)    PETROL    9100.0 KM   1st
#
#                        Location        Price
# 0            Ashok Vihar, Delhi  ₹ 29,00,000
# ...

# %%
df12 = pd.read_csv('olx_cars_19sept_4.csv',index_col=None)
df12
# Out:
#                             Model      Fuel Type     Mileage Owner  \
# 0         Hyundai Santa Fe (2012)         DIESEL  75000.0 KM   2nd
# 1            Hyundai Creta (2018)         DIESEL  52000.0 KM   1st
# 2    Mercedes-Benz E-Class (2011)         DIESEL  86000.0 KM   3rd
# 3            Hyundai Xcent (2020)  CNG & HYBRIDS  25000.0 KM   1st
# 4                  Audi A4 (2014)         DIESEL  87000.0 KM   1st
# ..                            ...            ...         ...   ...
# 219             Honda City (2016)         PETROL  37000.0 KM   1st
# 220      Hyundai Grand I10 (2019)         PETROL  36000.0 KM   1st
# 221    Maruti Suzuki Swift (2016)         DIESEL  78000.0 KM   1st
# 222             Honda City (2015)         DIESEL  89000.0 KM   1st
# 223                Audi A6 (2019)         DIESEL  19000.0 KM   1st
#
#                      Location        Price
# 0        Naranpura, Ahmedabad   ₹ 4,90,000
# 1        Sayajipura, Vadodara  ₹ 12,50,000
# ...

# %%
df_final_1 = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12],ignore_index=True)
df_final_1
# Out:
#                                 Model Fuel Type     Mileage Owner  \
# 0              Tata Indigo Ecs (2010)    PETROL  65000.0 KM   2nd
# 1    Maruti Suzuki Swift Dzire (2018)    DIESEL  32000.0 KM   1st
# 2         Maruti Suzuki Ertiga (2018)    DIESEL  48000.0 KM   1st
# 3                  Hyundai I10 (2013)    PETROL  68000.0 KM   2nd
# 4                    Tata Nano (2015)    PETROL  22000.0 KM   1st
# ..                                ...       ...         ...   ...
# 780                 Honda City (2016)    PETROL  37000.0 KM   1st
# 781          Hyundai Grand I10 (2019)    PETROL  36000.0 KM   1st
# 782        Maruti Suzuki Swift (2016)    DIESEL  78000.0 KM   1st
# 783                 Honda City (2015)    DIESEL  89000.0 KM   1st
# 784                    Audi A6 (2019)    DIESEL  19000.0 KM   1st
#
#                              Location        Price
# 0                Shastri Nagar, Delhi   ₹ 1,10,000
# 1    SR Nagar Colony, Tiruchirappalli   ₹ 7,90,000
# ...

# %%
df_final_1.to_csv('olx_cars_final_1.csv',index=False)
pd.read_csv('olx_cars_final_1.csv',index_col=None)
# Out:
#                                 Model Fuel Type     Mileage Owner  \
# 0              Tata Indigo Ecs (2010)    PETROL  65000.0 KM   2nd
# 1    Maruti Suzuki Swift Dzire (2018)    DIESEL  32000.0 KM   1st
# 2         Maruti Suzuki Ertiga (2018)    DIESEL  48000.0 KM   1st
# 3                  Hyundai I10 (2013)    PETROL  68000.0 KM   2nd
# 4                    Tata Nano (2015)    PETROL  22000.0 KM   1st
# ..                                ...       ...         ...   ...
# 780                 Honda City (2016)    PETROL  37000.0 KM   1st
# 781          Hyundai Grand I10 (2019)    PETROL  36000.0 KM   1st
# 782        Maruti Suzuki Swift (2016)    DIESEL  78000.0 KM   1st
# 783                 Honda City (2015)    DIESEL  89000.0 KM   1st
# 784                    Audi A6 (2019)    DIESEL  19000.0 KM   1st
#
#                              Location        Price
# 0                Shastri Nagar, Delhi   ₹ 1,10,000
# 1    SR Nagar Colony, Tiruchirappalli   ₹ 7,90,000
# ...

# %%
df13 = pd.read_csv('olx_cars_20sept_1.csv',index_col=None)
df13
# Out:
#                                 Model      Fuel Type     Mileage Owner  \
# 0                Hyundai Creta (2019)         DIESEL  59000.0 KM   1st
# 1    Maruti Suzuki Swift Dzire (2017)         DIESEL  56142.0 KM   1st
# 2                Toyota Innova (2016)         DIESEL  72000.0 KM   1st
# 3         Maruti Suzuki Baleno (2016)         PETROL  63000.0 KM   1st
# 4          Maruti Suzuki Swift (2012)         PETROL  74000.0 KM   2nd
# ..                                ...            ...         ...   ...
# 149           Mahindra Scorpio (2015)         DIESEL  76763.0 KM    --
# 150          Hyundai Elite I20 (2018)         PETROL  35818.0 KM   1st
# 151                Hyundai I20 (2021)         PETROL      1.0 KM    --
# 152      Maruti Suzuki Wagon R (2017)  CNG & HYBRIDS  130,000 KM   1st
# 153        Hyundai Santro Xing (2004)         PETROL  120,000 KM   2nd
#
#                           Location        Price
# 0           Navrangpura, Ahmedabad  ₹ 13,85,000
# ...

# %%
df14 = pd.read_csv('olx_cars_20sept_2.csv',index_col=None)
df14
# Out:
#                                Model      Fuel Type     Mileage Owner  \
# 0         Maruti Suzuki Swift (2019)         PETROL  13000.0 KM   1st
# 1             Mahindra Bolero (2013)         DIESEL  110,000 KM   2nd
# 2               Hyundai Creta (2017)         DIESEL   80,000 KM   2nd
# 3                 Hyundai I10 (2010)  CNG & HYBRIDS   88,600 KM   3rd
# 4               Toyota Innova (2009)         DIESEL  100,000 KM   2nd
# 5       Maruti Suzuki Wagon R (2016)  CNG & HYBRIDS  150,000 KM   1st
# 6               Hyundai Verna (2015)         PETROL  78000.0 KM   1st
# 7            Mahindra Scorpio (2014)         DIESEL   96,000 KM   1st
# 8          Maruti Suzuki Alto (2005)         PETROL  100,000 KM   2nd
# 9                 Hyundai I10 (2009)         PETROL  55000.0 KM   1st
# 10            Mahindra Xuv500 (2012)         DIESEL  84000.0 KM   2nd
# 11           Mahindra Scorpio (2011)         DIESEL   98,000 KM   2nd
# ...

# %%
df15 = pd.read_csv('olx_cars_20sept_3.csv',index_col=None)
df15
# Out:
#                                  Model      Fuel Type     Mileage Owner  \
# 0                   Honda Amaze (2015)         DIESEL  75000.0 KM   1st
# 1            Maruti Suzuki Ciaz (2018)         DIESEL  41000.0 KM   1st
# 2         Maruti Suzuki Wagon R (2014)  CNG & HYBRIDS  65000.0 KM   1st
# 3   Maruti Suzuki Vitara Brezza (2017)         DIESEL  35000.0 KM   1st
# 4            Maruti Suzuki Alto (2007)         PETROL  114,000 KM   2nd
# 5            Maruti Suzuki Ritz (2013)         DIESEL  145,000 KM   1st
# 6        Maruti Suzuki Alto K10 (2013)         PETROL   89,000 KM   2nd
# 7            Maruti Suzuki Eeco (2017)  CNG & HYBRIDS   56,000 KM   2nd
# 8             Maruti Suzuki 800 (2001)         PETROL   68,000 KM   2nd
# 9                   Hyundai I20 (2011)         DIESEL   98,000 KM   3rd
# 10                Hyundai Creta (2018)         DIESEL   42,000 KM   1st
# 11           Maruti Suzuki Eeco (2019)  CNG & HYBRIDS   50,000 KM   1st
# ...

# %%
df16 = pd.read_csv('olx_cars_20sept_4.csv',index_col=None)
df16
# Out:
#                            Model      Fuel Type     Mileage Owner  \
# 0          Chevrolet Beat (2012)         DIESEL   91,000 KM   2nd
# 1           Ford Ecosport (2013)         DIESEL  80000.0 KM    --
# 2              Honda City (2017)         DIESEL  76000.0 KM   1st
# 3               Ford Figo (2017)         DIESEL  87718.0 KM    --
# 4             Hyundai I10 (2009)         PETROL   63,000 KM   2nd
# ..                           ...            ...         ...   ...
# 63             Honda City (2018)         PETROL  39000.0 KM   1st
# 64            Hyundai I10 (2010)         PETROL  48000.0 KM   1st
# 65             Fiat Linea (2012)         DIESEL  105,000 KM   1st
# 66            Hyundai I10 (2011)  CNG & HYBRIDS  59000.0 KM   1st
# 67  Maruti Suzuki Wagon R (2015)         PETROL  88000.0 KM   1st
#
#                     Location       Price
# 0       Ram Chowk, Kharkhoda  ₹ 1,25,000
# 1       Rajiv Chowk, Gurgaon  ₹ 3,95,000
# 2         Model Town, Karnal  ₹ 8,60,000
# ...

# %%
df17 = pd.read_csv('olx_cars_20sept_5.csv',index_col=None)
df17
# Out:
#                           Model Fuel Type      Mileage Owner  \
# 0       Mahindra Scorpio (2013)    DIESEL    80,000 KM   1st
# 1       Volkswagen Vento (2011)    DIESEL   115,000 KM   1st
# 2    Hyundai Santro Xing (2009)    PETROL    60,500 KM   2nd
# 3             Honda Brio (2013)    DIESEL  800000.0 KM   1st
# 4            Tata Safari (2010)    DIESEL   100,000 KM   1st
# ..                          ...       ...          ...   ...
# 163          Hyundai I10 (2013)    PETROL   77000.0 KM   1st
# 164       Chevrolet Beat (2014)    DIESEL   76000.0 KM   1st
# 165           Kia Seltos (2019)    PETROL   26000.0 KM   1st
# 166          Hyundai I20 (2013)    DIESEL   88000.0 KM   1st
# 167       Chevrolet Beat (2012)    DIESEL    69,500 KM   2nd
#
#                                Location        Price
# 0                    Dav Colony, Cheeka   ₹ 4,30,000
# 1    Rehawar, Industrial Estate Barwala   ₹ 3,00,000
# 2                 Guhla Village, Cheeka   ₹ 1,55,000
# ...

# %%
df18 = pd.read_csv('olx_cars_23sept_1.csv',index_col=None)
df18
# Out:
#                                  Model      Fuel Type      Mileage Owner  \
# 0                   Tata Indica (2009)         DIESEL   114,000 KM   3rd
# 1               Volkswagen Polo (2015)         PETROL    56,000 KM   2nd
# 2                    Kia Seltos (2019)         PETROL   30000.0 KM   1st
# 3                    Honda City (2019)         DIESEL   21000.0 KM   1st
# 4            Maruti Suzuki Ciaz (2016)         DIESEL   80203.0 KM    --
# 5                   Hyundai Eon (2018)         PETROL   44787.0 KM   1st
# 6                    Honda Brio (2017)         PETROL   10000.0 KM   1st
# 7             Maruti Suzuki 800 (2008)         PETROL   87000.0 KM   1st
# 8     Maruti Suzuki Swift Dzire (2017)         DIESEL   82000.0 KM   1st
# 9               Mahindra Bolero (2012)         DIESEL   127,000 KM   1st
# 10                  Hyundai I10 (2010)         PETROL   70000.0 KM   1st
# 11       Maruti Suzuki Alto K10 (2019)         PETROL   28000.0 KM   1st
# ...

# %%
df19 = pd.read_csv('olx_cars_23sept_2.csv',index_col=None)
df19
# Out:
#                    Model Fuel Type     Mileage Owner  \
# 0   Ford Ecosport (2014)    DIESEL  61500.0 KM   1st
# 1     Tata Others (2016)    DIESEL  100,000 KM   2nd
# 2  Ford Endeavour (2017)    DIESEL   50,000 KM   1st
#
#                              Location        Price
# 0                    MG Road, Gurgaon   ₹ 4,59,000
# 1  Shree Ranbir Lohan Block, Narnaund   ₹ 6,70,000
# 2          Mohmmadpur Jharsa, Gurgaon  ₹ 24,90,000

# %%
df20 = pd.read_csv('olx_cars_23sept_3.csv',index_col=None)
df20
# Out:
#                               Model      Fuel Type      Mileage Owner  \
# 0               Renault Kwid (2016)         PETROL   44000.0 KM   1st
# 1          Toyota Etios Liva (2015)         DIESEL   78000.0 KM   1st
# 2          Maruti Suzuki Sx4 (2010)         PETROL   41000.0 KM   1st
# 3                    Audi Q7 (2014)         DIESEL    48,000 KM   1st
# 4         Maruti Suzuki Eeco (2016)  CNG & HYBRIDS   110,000 KM   2nd
# 5                    Audi Q5 (2015)         DIESEL   34000.0 KM   1st
# 6   Maruti Suzuki Zen Estilo (2009)         PETROL    65,000 KM   2nd
# 7     Maruti Suzuki Alto 800 (2019)         PETROL    17,290 KM   2nd
# 8       Toyota Innova Crysta (2017)         DIESEL   35000.0 KM   1st
# 9      Maruti Suzuki Wagon R (2009)         PETROL    82,000 KM   1st
# 10               Hyundai I10 (2011)         PETROL   50000.0 KM   2nd
# 11      Toyota Corolla Altis (2010)         PETROL   72000.0 KM   1st
# ...

# %%
df21 = pd.read_csv('olx_cars_23sept_4.csv',index_col=None)
df21
# Out:
#                             Model      Fuel Type     Mileage Owner  \
# 0       Maruti Suzuki Alto (2006)  CNG & HYBRIDS   25,000 KM   3rd
# 1              Skoda Rapid (2012)         PETROL  36000.0 KM   1st
# 2       Maruti Suzuki Ritz (2016)         DIESEL   68,215 KM   2nd
# 3   Maruti Suzuki S-Presso (2019)         PETROL  66547.0 KM    --
# 4      Maruti Suzuki Ignis (2018)         PETROL  18224.0 KM   1st
# ..                            ...            ...         ...   ...
# 90  Maruti Suzuki Alto K10 (2013)         PETROL  69000.0 KM    --
# 91        Mahindra Scorpio (2009)         DIESEL      1.0 KM   1st
# 92              Honda City (2016)         PETROL  70000.0 KM   1st
# 93             Tata Others (2014)         DIESEL    119.0 KM   2nd
# 94   Maruti Suzuki Wagon R (2018)         PETROL      3.0 KM    --
#
#                                  Location       Price
# 0                 Nangal Kalan 43, Kundli    ₹ 40,000
# ...

# %%
df22 = pd.read_csv('olx_cars_23sept_5.csv',index_col=None)
df22
# Out:
#                         Model Fuel Type     Mileage Owner  \
# 0  Maruti Suzuki Swift (2017)        --  36223.0 KM   1st
# 1            Tata Nano (2013)    PETROL  90184.0 KM   2nd
# 2   Maruti Suzuki Eeco (2017)    PETROL   42,000 KM   2nd
# 3  Maruti Suzuki Swift (2007)    DIESEL  130,000 KM   4th
#
#                        Location       Price
# 0        Eranhipalam, Kozhikode  ₹ 5,90,000
# 1        Eranhipalam, Kozhikode    ₹ 80,000
# 2  Thrikkariyoor, Kothamangalam  ₹ 3,49,000
# 3           Morayur, Malappuram  ₹ 1,65,000

# %%
df23 = pd.read_csv('olx_cars_23sept_6.csv',index_col=None)
df23
# Out:
#                                Model Fuel Type      Mileage Owner  \
# 0       Maruti Suzuki Celerio (2019)    PETROL      88.0 KM    --
# 1                 Ford Fiesta (2009)    PETROL  118000.0 KM   1st
# 2         Maruti Suzuki Swift (2018)    DIESEL   59000.0 KM   1st
# 3               Toyota Innova (2009)    DIESEL  126000.0 KM   2nd
# 4                     Audi A4 (2015)    DIESEL   76000.0 KM   1st
# 5                 Hyundai I10 (2012)    PETROL   75000.0 KM   2nd
# 6            Mahindra Scorpio (2009)    DIESEL  112000.0 KM   3rd
# 7        Maruti Suzuki Estilo (2009)        --   92000.0 KM   2nd
# 8                  Tata Tiago (2018)    PETROL   68000.0 KM   2nd
# 9                   Tata Nano (2015)    PETROL   29000.0 KM   1st
# 10        Maruti Suzuki Swift (2016)    DIESEL   55000.0 KM   1st
# 11         Maruti Suzuki Alto (2010)    PETROL  108813.0 KM   1st
# 12            Mahindra Xuv500 (2012)    DIESEL         2 KM   2nd
# ...

# %%
df24 = pd.read_csv('olx_cars_23sept_7.csv',index_col=None)
df24
# Out:
#                              Model Fuel Type      Mileage Owner  \
# 0             Toyota Innova (2008)    DIESEL  241666.0 KM   2nd
# 1     Maruti Suzuki Celerio (2017)    PETROL   66000.0 KM   2nd
# 2               Honda Amaze (2016)    PETROL   35555.0 KM   1st
# 3    Maruti Suzuki Alto K10 (2011)    PETROL   30118.0 KM   1st
# 4     Maruti Suzuki Wagon R (2017)    PETROL   53835.0 KM   1st
# 5   Mitsubishi Pajero Sport (2012)    DIESEL  135000.0 KM   2nd
# 6             Hyundai Verna (2011)    DIESEL    91,770 KM   1st
# 7               Hyundai I20 (2009)    DIESEL   162,000 KM   3rd
# 8        Maruti Suzuki Ciaz (2016)    PETROL   51036.0 KM   1st
# 9       Maruti Suzuki Swift (2014)    DIESEL    52,000 KM   1st
# 10           Renault Others (2021)    PETROL     2,800 KM   1st
# 11           Tata Indigo Cs (2008)    DIESEL         0 KM   2nd
# 12     Maruti Suzuki A-Star (2009)    PETROL    63,000 KM   1st
# 13    Maruti Suzuki Wagon R (2010)    PETROL   78000.0 KM   2nd
# ...

# %%
df25 = pd.read_csv('olx_cars_23sept_8.csv',index_col=None)
df25
# Out:
#                            Model Fuel Type     Mileage Owner  \
# 0  Maruti Suzuki Alto 800 (2014)        --  79486.0 KM   2nd
# 1       Maruti Suzuki Zen (1997)    PETROL  121,000 KM   2nd
# 2          Renault Triber (2020)        --  15000.0 KM    --
# 3          Renault Triber (2020)        --  15000.0 KM    --
#
#                      Location       Price
# 0         Palarivattom, Kochi  ₹ 2,25,000
# 1       Koottupatha, Palakkad    ₹ 37,000
# 2  Muvattupuzha, Muvattupuzha  ₹ 7,10,000
# 3           Kolenchery, Kochi  ₹ 7,10,000

# %%
df26 = pd.read_csv('olx_cars_23sept_9.csv',index_col=None)
df26
# Out:
#                            Model Fuel Type     Mileage Owner  \
# 0      Maruti Suzuki Ciaz (2017)        --  17205.0 KM   1st
# 1           Ford Ecosport (2014)    DIESEL   98,700 KM   2nd
# 2             Tata Others (2018)    DIESEL  33000.0 KM   1st
# 3                 Audi A6 (2010)        --   5656.0 KM    --
# 4    Maruti Suzuki Ertiga (2018)    PETROL   36,000 KM   1st
# ..                           ...       ...         ...   ...
# 57  Maruti Suzuki Wagon R (2009)    PETROL   88,625 KM   1st
# 58     Maruti Suzuki Omni (2002)    PETROL   32,000 KM    4+
# 59     Hyundai Getz Prime (2008)    PETROL   81,574 KM   3rd
# 60          Mahindra Jeep (1986)    DIESEL  890,000 KM    4+
# 61   Maruti Suzuki Estilo (2007)    PETROL  98000.0 KM   2nd
#
#                             Location       Price
# 0                Palarivattom, Kochi  ₹ 8,10,000
# 1   Nellaya Village, Vaniyamkulam II  ₹ 5,90,000
# 2                  Vengoor, Angamaly  ₹ 4,75,000
# ...

# %%
df27 = pd.read_csv('olx_cars_23sept_10.csv',index_col=None)
df27
# Out:
#                        Model Fuel Type      Mileage Owner  \
# 0         Tata Others (2017)        --   75000.0 KM    4+
# 1         Hyundai I20 (2011)    DIESEL  135000.0 KM   2nd
# 2    Chevrolet Tavera (2005)    DIESEL   270,000 KM   3rd
# 3       Toyota Innova (2013)    DIESEL  150000.0 KM   2nd
# 4           Tata Zest (2015)    DIESEL   108,000 KM   1st
# 5  Maruti Suzuki Ritz (2012)    DIESEL   93831.0 KM   2nd
#
#                  Location        Price
# 0      Kainatty, Kalpetta   ₹ 2,50,000
# 1  Palat Nagar, Kozhikode   ₹ 2,40,000
# 2      Cherupuzha, Kannur   ₹ 2,50,000
# 3    Mebaram, Thazhuthala  ₹ 10,85,000
# 4    Manakkad, Thodupuzha   ₹ 4,50,000
# 5      Kalamassery, Kochi   ₹ 3,45,000

# %%
df28 = pd.read_csv('olx_cars_23sept_11.csv',index_col=None)
df28
# Out:
#                                 Model Fuel Type      Mileage Owner  \
# 0         Toyota Corolla Altis (2015)    PETROL    26,000 KM   2nd
# 1           Maruti Suzuki Ritz (2010)    PETROL    82,000 KM   2nd
# 2            Maruti Suzuki 800 (1998)    PETROL   100,000 KM   3rd
# 3         Toyota Corolla Altis (2011)    DIESEL   170,000 KM   3rd
# 4               Renault Triber (2020)        --   15001.0 KM    --
# ..                                ...       ...          ...   ...
# 499  Maruti Suzuki Swift Dzire (2014)    PETROL    53,000 KM   3rd
# 500                 Honda Brio (2014)    PETROL   47325.0 KM   1st
# 501            Toyota Fortuner (2010)    DIESEL  183000.0 KM   1st
# 502            Volkswagen Polo (2010)    DIESEL   160,000 KM   3rd
# 503        Maruti Suzuki Swift (2005)    PETROL    10,300 KM    4+
#
#                                     Location        Price
# 0                    Kumbankalli, Thodupuzha  ₹ 10,95,000
# ...

# %%
df_final_2 = pd.concat([df_final_1,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28],ignore_index=True)
df_final_2
# Out:
#                                  Model Fuel Type      Mileage Owner  \
# 0               Tata Indigo Ecs (2010)    PETROL   65000.0 KM   2nd
# 1     Maruti Suzuki Swift Dzire (2018)    DIESEL   32000.0 KM   1st
# 2          Maruti Suzuki Ertiga (2018)    DIESEL   48000.0 KM   1st
# 3                   Hyundai I10 (2013)    PETROL   68000.0 KM   2nd
# 4                     Tata Nano (2015)    PETROL   22000.0 KM   1st
# ...                                ...       ...          ...   ...
# 2025  Maruti Suzuki Swift Dzire (2014)    PETROL    53,000 KM   3rd
# 2026                 Honda Brio (2014)    PETROL   47325.0 KM   1st
# 2027            Toyota Fortuner (2010)    DIESEL  183000.0 KM   1st
# 2028            Volkswagen Polo (2010)    DIESEL   160,000 KM   3rd
# 2029        Maruti Suzuki Swift (2005)    PETROL    10,300 KM    4+
#
#                               Location        Price
# 0                 Shastri Nagar, Delhi   ₹ 1,10,000
# ...

# %%
df_final_2.to_csv('olx_cars_final_2.csv',index=False)
pd.read_csv('olx_cars_final_2.csv',index_col=None)
# Out:
#                                  Model Fuel Type      Mileage Owner  \
# 0               Tata Indigo Ecs (2010)    PETROL   65000.0 KM   2nd
# 1     Maruti Suzuki Swift Dzire (2018)    DIESEL   32000.0 KM   1st
# 2          Maruti Suzuki Ertiga (2018)    DIESEL   48000.0 KM   1st
# 3                   Hyundai I10 (2013)    PETROL   68000.0 KM   2nd
# 4                     Tata Nano (2015)    PETROL   22000.0 KM   1st
# ...                                ...       ...          ...   ...
# 2025  Maruti Suzuki Swift Dzire (2014)    PETROL    53,000 KM   3rd
# 2026                 Honda Brio (2014)    PETROL   47325.0 KM   1st
# 2027            Toyota Fortuner (2010)    DIESEL  183000.0 KM   1st
# 2028            Volkswagen Polo (2010)    DIESEL   160,000 KM   3rd
# 2029        Maruti Suzuki Swift (2005)    PETROL    10,300 KM    4+
#
#                               Location        Price
# 0                 Shastri Nagar, Delhi   ₹ 1,10,000
# ...

# %%
df29 = pd.read_csv('olx_cars_24sept_1.csv',index_col=None)
df29
# Out:
#                                Model Fuel Type      Mileage Owner  \
# 0           Tata Indica Vista (2010)    PETROL    58,000 KM   1st
# 1   Maruti Suzuki Swift Dzire (2019)    DIESEL    84,211 KM   1st
# 2                  Honda City (2015)    PETROL   22000.0 KM   1st
# 3           Hyundai Elite I20 (2018)    PETROL   11000.0 KM   1st
# 4             Toyota Fortuner (2014)    DIESEL  101000.0 KM   2nd
# ..                               ...       ...          ...   ...
# 90              Honda City Zx (2007)    PETROL    79,042 KM   2nd
# 91                  Mg Hector (2019)    PETROL    11,000 KM   1st
# 92                    Audi A4 (2015)    DIESEL   44000.0 KM   2nd
# 93              Renault Lodgy (2017)    DIESEL   79863.0 KM   1st
# 94        Hyundai Santro Xing (2012)    PETROL   29000.0 KM   1st
#
#                            Location        Price
# 0              Molkotta, Sankeshwar   ₹ 1,99,000
# 1     Anand Gokul Layout, Bengaluru   ₹ 6,00,000
# ...

# %%
df30 = pd.read_csv('olx_cars_24sept_2.csv',index_col=None)
df30
# Out:
#                           Model Fuel Type     Mileage Owner  \
# 0             Honda City (2012)    PETROL   83,000 KM   1st
# 1    Ashok Leyland Stile (2015)    DIESEL  111,800 KM   2nd
# 2            Hyundai Eon (2012)    PETROL  35000.0 KM   1st
# 3         Hyundai Accent (2010)    PETROL  72000.0 KM   1st
# 4         Ford Endeavour (2016)    DIESEL  50000.0 KM   1st
# ..                          ...       ...         ...   ...
# 176       Chevrolet Beat (2011)    PETROL  51000.0 KM   2nd
# 177     Volkswagen Vento (2012)    PETROL  53000.0 KM   1st
# 178     Mahindra Tuv 300 (2016)    DIESEL  62000.0 KM   1st
# 179      Volkswagen Ameo (2017)    DIESEL  35393.0 KM   1st
# 180      Volkswagen Polo (2013)    PETROL  46000.0 KM   1st
#
#                                               Location        Price
# 0                             Wheelers Road, Bengaluru   ₹ 5,00,000
# 1                                  RT Nagar, Bengaluru   ₹ 4,55,000
# ...

# %%
df31 = pd.read_csv('olx_cars_24sept_3.csv',index_col=None)
df31
# Out:
#                                 Model      Fuel Type     Mileage Owner  \
# 0    Maruti Suzuki Wagon R 1.0 (2013)  CNG & HYBRIDS  70235.0 KM   1st
# 1         Maruti Suzuki Ertiga (2021)  CNG & HYBRIDS    123.0 KM    --
# 2             Volkswagen Vento (2016)         DIESEL  81000.0 KM   1st
# 3                Hyundai Creta (2015)         PETROL  48000.0 KM   1st
# 4         Maruti Suzuki Ertiga (2015)         PETROL  75000.0 KM   1st
# ..                                ...            ...         ...   ...
# 131  Maruti Suzuki Swift Dzire (2014)         PETROL  44060.0 KM   1st
# 132              Hyundai Creta (2017)         DIESEL  64530.0 KM   1st
# 133  Maruti Suzuki Swift Dzire (2013)         PETROL  55140.0 KM   1st
# 134            Volkswagen Polo (2015)         PETROL  65500.0 KM   2nd
# 135                Hyundai I20 (2011)         PETROL  47200.0 KM   1st
#
#                  Location        Price
# 0          Deonar, Mumbai   ₹ 2,97,000
# ...

# %%
df32 = pd.read_csv('olx_cars_25sept_1.csv',index_col=None)
df32
# Out:
#                            Model      Fuel Type     Mileage Owner  \
# 0           Hyundai Verna (2015)         DIESEL  82000.0 KM   1st
# 1       Hyundai Elite I20 (2015)         PETROL  48000.0 KM   2nd
# 2    Maruti Suzuki Ertiga (2018)         DIESEL  29000.0 KM   1st
# 3           Hyundai Xcent (2016)         DIESEL  53155.0 KM    --
# 4    Maruti Suzuki Baleno (2017)         DIESEL  34000.0 KM   1st
# ..                           ...            ...         ...   ...
# 244  Chevrolet Tavera Neo (2013)         DIESEL  120,000 KM   2nd
# 245     Maruti Suzuki 800 (2005)  CNG & HYBRIDS  250,000 KM    4+
# 246         Hyundai Verna (2011)         DIESEL   44,000 KM   3rd
# 247            Honda Brio (2011)         PETROL  47318.0 KM   1st
# 248        Chevrolet Beat (2011)         DIESEL  67000.0 KM   1st
#
#                        Location        Price
# 0           Adgaon Naka, Nashik   ₹ 6,41,000
# 1     Wagholi Ubale Nagar, Pune   ₹ 5,75,000
# ...

# %%
df33 = pd.read_csv('olx_cars_25sept_2.csv',index_col=None)
df33
# Out:
#                                   Model      Fuel Type      Mileage Owner  \
# 0                Toyota Fortuner (2011)         DIESEL  170000.0 KM   1st
# 1               Mahindra Scorpio (2014)         DIESEL        15 KM   3rd
# 2              Maruti Suzuki 800 (1998)            LPG    62,000 KM   2nd
# 3                Mahindra Bolero (2010)         DIESEL    96,000 KM   1st
# 4    Maruti Suzuki Vitara Brezza (2016)         DIESEL    60,000 KM   2nd
# ..                                  ...            ...          ...   ...
# 162                  Ford Aspire (2020)         DIESEL    30,000 KM   1st
# 163                   Tata Manza (2010)         DIESEL    79,000 KM   2nd
# 164           Maruti Suzuki Eeco (2012)  CNG & HYBRIDS     9,000 KM   3rd
# 165          Hyundai Santro Xing (2010)         PETROL    70,300 KM   2nd
# 166           Maruti Suzuki Alto (2011)            LPG   100,000 KM   1st
#
#                                        Location        Price
# ...

# %%
df34 = pd.read_csv('olx_cars_26sept_1.csv',index_col=None)
df34
# Out:
#                                 Model Fuel Type      Mileage Owner  \
# 0    Maruti Suzuki Swift Dzire (2012)    DIESEL    60,000 KM   2nd
# 1        Maruti Suzuki Wagon R (2009)    PETROL   50000.0 KM   2nd
# 2          Hyundai Santro Xing (2004)       LPG    92,000 KM   1st
# 3           Maruti Suzuki Alto (2006)    PETROL    69,048 KM   2nd
# 4                  Hyundai I20 (2012)    DIESEL    60,000 KM   1st
# ..                                ...       ...          ...   ...
# 396        Maruti Suzuki Swift (2014)    DIESEL   147,000 KM   2nd
# 397          Tata Indica Vista (2011)    DIESEL    80,000 KM   1st
# 398        Maruti Suzuki Swift (2007)    DIESEL    97,568 KM   2nd
# 399        Maruti Suzuki Ignis (2019)    PETROL    8500.0 KM   1st
# 400       Toyota Innova Crysta (2017)    PETROL  120000.0 KM   1st
#
#                             Location        Price
# 0                Mohalpura, Jabalpur   ₹ 3,50,000
# 1            Palsikar Colony, Indore   ₹ 2,00,000
# ...

# %%
df35 = pd.read_csv('olx_cars_26sept_2.csv',index_col=None)
df35
# Out:
#                                   Model Fuel Type     Mileage Owner  \
# 0    Maruti Suzuki Vitara Brezza (2019)    DIESEL  24000.0 KM   1st
# 1                Toyota Fortuner (2010)    DIESEL  149,000 KM   3rd
# 2                     Honda City (2005)    PETROL  120,000 KM   2nd
# 3    Maruti Suzuki Vitara Brezza (2019)    DIESEL   43,000 KM   1st
# 4         Maruti Suzuki Alto 800 (2011)    PETROL   45,500 KM   2nd
# ..                                  ...       ...         ...   ...
# 217          Maruti Suzuki Swift (2015)    PETROL  52000.0 KM   1st
# 218    Maruti Suzuki Swift Dzire (2014)    DIESEL  72000.0 KM   1st
# 219                Mahindra Xylo (2010)    DIESEL  65000.0 KM   2nd
# 220           Maruti Suzuki Omni (2018)    PETROL  45000.0 KM   1st
# 221                  Skoda Rapid (2016)    DIESEL  62000.0 KM   2nd
#
#                                   Location       Price
# 0             Jujhar Singh Nagar, Bathinda  ₹ 9,00,000
# ...

# %%
df36 = pd.read_csv('olx_cars_26sept_3.csv',index_col=None)
df36
# Out:
#                                    Model      Fuel Type      Mileage Owner  \
# 0                Mahindra Scorpio (2005)         DIESEL  125000.0 KM    4+
# 1              Maruti Suzuki Omni (2016)         PETROL   50000.0 KM   1st
# 2                   Renault Lodgy (2016)         DIESEL   50000.0 KM   1st
# 3                  Chevrolet Aveo (2007)         PETROL   65000.0 KM   1st
# 4       Maruti Suzuki Swift Dzire (2014)         PETROL   88000.0 KM   1st
# ..                                   ...            ...          ...   ...
# 144             Maruti Suzuki 800 (2007)            LPG       350 KM   2nd
# 145     Maruti Suzuki Swift Dzire (2017)         DIESEL   125,000 KM   2nd
# 146               Mahindra Bolero (2012)         DIESEL   180,000 KM   2nd
# 147  Land Rover Range Rover Sport (2018)         DIESEL   22000.0 KM   1st
# 148                    Honda City (2009)  CNG & HYBRIDS    66,000 KM   2nd
#
#                                   Location          Price
# ...

# %%
df37 = pd.read_csv('olx_cars_27sept_1.csv',index_col=None)
df37
# Out:
#                            Model Fuel Type     Mileage Owner  \
# 0      Maruti Suzuki Alto (2005)       LPG  100,000 KM   3rd
# 1         Mahindra Bolero (2021)    DIESEL   15,000 KM   1st
# 2             Honda Amaze (2015)    DIESEL  60000.0 KM   1st
# 3       Maruti Suzuki 800 (2009)    PETROL       25 KM   3rd
# 4      Maruti Suzuki Eeco (2012)    DIESEL       17 KM   1st
# 5              Tata Nexon (2019)    PETROL  19000.0 KM   1st
# 6   Maruti Suzuki Celerio (2017)    PETROL       22 KM   1st
# 7  Mahindra Bolero Pik-Up (2019)    DIESEL   65,000 KM   1st
# 8   Maruti Suzuki Wagon R (2011)    PETROL  64000.0 KM   3rd
#
#                        Location        Price
# 0              Megras, Bhilwara   ₹ 1,10,000
# 1               5 Kwd, Rawatsar  ₹ 10,25,000
# 2  Railway Station Area, Jaipur   ₹ 5,00,000
# 3   Siluwali Baadi, Hanumangarh   ₹ 1,50,000
# 4               Anantpura, Kota   ₹ 3,00,000
# 5             Bikaneri, Bikaner   ₹ 7,75,000
# ...

# %%
df38 = pd.read_csv('olx_cars_27sept_2.csv',index_col=None)
df38
# Out:
#                                Model      Fuel Type      Mileage Owner  \
# 0      Maruti Suzuki Alto K10 (2012)         PETROL    79,000 KM   4th
# 1              Hyundai Accent (2007)         DIESEL    77,000 KM   2nd
# 2             Mahindra Bolero (2005)         DIESEL   179,200 KM   2nd
# 3               Toyota Innova (2015)         DIESEL   211,000 KM   2nd
# 4               Renault Scala (2013)         DIESEL   105,000 KM   1st
# 5    Maruti Suzuki Zen Estilo (2007)         PETROL    73,000 KM   3rd
# 6            Mahindra Scorpio (2008)         DIESEL   400,000 KM   1st
# 7                 Skoda Rapid (2012)         DIESEL   67000.0 KM   1st
# 8       Maruti Suzuki Wagon R (2010)            LPG   67000.0 KM   1st
# 9             Chevrolet Spark (2009)         PETROL   78000.0 KM   1st
# 10         Maruti Suzuki Ritz (2012)         DIESEL   135,000 KM   1st
# 11        Hyundai Santro Xing (2010)  CNG & HYBRIDS   101,000 KM   2nd
# ...

# %%
df39 = pd.read_csv('olx_cars_27sept_3.csv',index_col=None)
df39
# Out:
#                                   Model Fuel Type     Mileage Owner  \
# 0                Mahindra Bolero (2017)    DIESEL  84000.0 KM    --
# 1                     Honda Wr-V (2017)    PETROL   9300.0 KM   1st
# 2                    Ford Fiesta (2013)    DIESEL  53000.0 KM   1st
# 3      Maruti Suzuki Wagon R 1.0 (2007)    PETROL   68,000 KM   3rd
# 4         Maruti Suzuki Alto 800 (2018)    PETROL   35,000 KM   2nd
# ..                                  ...       ...         ...   ...
# 409  Maruti Suzuki Vitara Brezza (2019)    DIESEL  71000.0 KM   1st
# 410                   Honda Brio (2015)    PETROL  32000.0 KM   1st
# 411                  Hyundai I10 (2010)    PETROL   47,000 KM   1st
# 412                   Volvo Xc40 (2020)    PETROL  12057.0 KM   1st
# 413           maruti suzuki alto (2007)    Petrol  74551.0 Km   1st
#
#                                     Location        Price
# 0    Luhar Colony, Kishangarh Ajmer District   ₹ 7,50,000
# ...

# %%
df_final_3 = pd.concat([df_final_2,df29,df30,df31,df32,df33,df34,df35,df36,df37,df38,df39],ignore_index=True)
df_final_3
# Out:
#                                    Model Fuel Type     Mileage Owner  \
# 0                 Tata Indigo Ecs (2010)    PETROL  65000.0 KM   2nd
# 1       Maruti Suzuki Swift Dzire (2018)    DIESEL  32000.0 KM   1st
# 2            Maruti Suzuki Ertiga (2018)    DIESEL  48000.0 KM   1st
# 3                     Hyundai I10 (2013)    PETROL  68000.0 KM   2nd
# 4                       Tata Nano (2015)    PETROL  22000.0 KM   1st
# ...                                  ...       ...         ...   ...
# 4070  Maruti Suzuki Vitara Brezza (2019)    DIESEL  71000.0 KM   1st
# 4071                   Honda Brio (2015)    PETROL  32000.0 KM   1st
# 4072                  Hyundai I10 (2010)    PETROL   47,000 KM   1st
# 4073                   Volvo Xc40 (2020)    PETROL  12057.0 KM   1st
# 4074           maruti suzuki alto (2007)    Petrol  74551.0 Km   1st
#
#                               Location        Price
# 0                 Shastri Nagar, Delhi   ₹ 1,10,000
# ...

# %%
df_final_3.to_csv('olx_cars_final_3.csv',index=False)
pd.read_csv('olx_cars_final_3.csv',index_col=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_44236/1049994114.py in <module>
# ----> 1 df_final_3.to_csv('olx_cars_final_3.csv',index=False)
#       2 pd.read_csv('olx_cars_final_3.csv',index_col=None)
#
# NameError: name 'df_final_3' is not defined

# %%
df_final_3 = pd.read_csv('olx_cars_final_3.csv',index_col=None)

# %%
df_final_3
# Out:
#                                    Model Fuel Type     Mileage Owner  \
# 0                 Tata Indigo Ecs (2010)    PETROL  65000.0 KM   2nd
# 1       Maruti Suzuki Swift Dzire (2018)    DIESEL  32000.0 KM   1st
# 2            Maruti Suzuki Ertiga (2018)    DIESEL  48000.0 KM   1st
# 3                     Hyundai I10 (2013)    PETROL  68000.0 KM   2nd
# 4                       Tata Nano (2015)    PETROL  22000.0 KM   1st
# ...                                  ...       ...         ...   ...
# 4070  Maruti Suzuki Vitara Brezza (2019)    DIESEL  71000.0 KM   1st
# 4071                   Honda Brio (2015)    PETROL  32000.0 KM   1st
# 4072                  Hyundai I10 (2010)    PETROL   47,000 KM   1st
# 4073                   Volvo Xc40 (2020)    PETROL  12057.0 KM   1st
# 4074           maruti suzuki alto (2007)    Petrol  74551.0 Km   1st
#
#                               Location        Price
# 0                 Shastri Nagar, Delhi   ₹ 1,10,000
# ...

# %%
df1 = pd.read_csv('olx_cars_28sept_1.csv',index_col=None)
df1
# Out:
#                                 Model Fuel Type      Mileage Owner  \
# 0         Maruti Suzuki Baleno (2016)    PETROL   68660.0 KM   1st
# 1       Maruti Suzuki Alto K10 (2012)    PETROL   70585.0 KM   1st
# 2              Mahindra Bolero (2017)    DIESEL    95,000 KM   2nd
# 3           Maruti Suzuki Omni (2008)    PETROL   110,000 KM   2nd
# 4        Eicher Polaris Others (2011)    DIESEL   140,000 KM   1st
# ..                                ...       ...          ...   ...
# 108           Mahindra Scorpio (2009)    DIESEL   177,000 KM   2nd
# 109    Mitsubishi Pajero Sport (2014)    DIESEL  125089.0 KM   1st
# 110            Tata Indica Ev2 (2016)    DIESEL   90000.0 KM   2nd
# 111  Maruti Suzuki Swift Dzire (2017)    PETROL   32931.0 KM    --
# 112                  Volvo S60 (2016)    DIESEL    47,300 KM   1st
#
#                                Location        Price
# 0                   Madhapur, Hyderabad   ₹ 6,20,000
# 1                 Bowenpally, Hyderabad   ₹ 2,49,000
# ...

# %%
df2 = pd.read_csv('olx_cars_28sept_2.csv',index_col=None)
df2
# Out:
#                             Model Fuel Type      Mileage Owner  \
# 0            Toyota Innova (2012)    DIESEL  127000.0 KM   1st
# 1      Maruti Suzuki Swift (2015)    DIESEL   112,000 KM   1st
# 2               Tata Tiago (2016)    PETROL   70000.0 KM   1st
# 3               Tata Manza (2010)    DIESEL   170,000 KM   2nd
# 4      Hyundai Santro Xing (2003)    PETROL    61,000 KM   2nd
# ..                            ...       ...          ...   ...
# 188          Toyota Innova (2009)    DIESEL  229000.0 KM   2nd
# 189  Hyundai Fluidic Verna (2014)    DIESEL   61000.0 KM   2nd
# 190            Honda Amaze (2013)    DIESEL   80794.0 KM    --
# 191       Mahindra Scorpio (2007)    DIESEL  169000.0 KM   2nd
# 192            Hyundai Eon (2014)    PETROL   20000.0 KM   1st
#
#                                          Location       Price
# 0                            Erragadda, Hyderabad  ₹ 8,50,000
# 1                      IDA Cherlapalli, Hyderabad  ₹ 5,90,000
# ...

# %%
df3 = pd.read_csv('olx_cars_28sept_3.csv',index_col=None)
df3
# Out:
#                 Model Fuel Type     Mileage Owner                  Location  \
# 0  Hyundai I10 (2011)    PETROL  48000.0 KM   1st  Chennai Central, Chennai
#
#         Price
# 0  ₹ 3,30,000

# %%
df4 = pd.read_csv('olx_cars_29sept_1.csv',index_col=None)
df4
# Out:
#                                     Model Fuel Type      Mileage Owner  \
# 0                    Hyundai Verna (2016)    PETROL   31000.0 KM   1st
# 1                       Honda Brio (2013)    PETROL   32000.0 KM   1st
# 2                    Toyota Innova (2011)    DIESEL  228507.0 KM   2nd
# 3                  Mahindra Bolero (2006)    DIESEL  188000.0 KM   2nd
# 4               Maruti Suzuki Alto (2011)    PETROL   26000.0 KM   1st
# ..                                    ...       ...          ...   ...
# 76            Toyota Innova Crysta (2018)    DIESEL  113000.0 KM   2nd
# 77  Maruti Suzuki Swift Dzire Tour (2018)    DIESEL   61000.0 KM   1st
# 78                Mahindra Scorpio (2016)    DIESEL   97000.0 KM   1st
# 79             Maruti Suzuki Swift (2016)    DIESEL   64000.0 KM   1st
# 80                 Mahindra Xuv500 (2012)    DIESEL  130000.0 KM   1st
#
#                            Location        Price
# 0     Chromepet New Colony, Chennai   ₹ 7,45,000
# ...

# %%
df5 = pd.read_csv('olx_cars_29sept_2.csv',index_col=None)
df5
# Out:
#                             Model Fuel Type      Mileage Owner  \
# 0    Maruti Suzuki Wagon R (2011)    PETROL    72,000 KM   2nd
# 1            Toyota Innova (2009)    DIESEL  210000.0 KM   2nd
# 2           Chevrolet Beat (2010)    PETROL   17000.0 KM   1st
# 3              Hyundai I10 (2011)    PETROL   41000.0 KM   2nd
# 4              Hyundai I10 (2011)    PETROL   41000.0 KM   2nd
# ..                            ...       ...          ...   ...
# 229    Maruti Suzuki Swift (2011)    DIESEL   70000.0 KM    --
# 230        Toyota Fortuner (2009)    DIESEL   140,000 KM    --
# 231           Renault Kwid (2021)    PETROL    4000.0 KM   1st
# 232    Maruti Suzuki Ignis (2019)    PETROL   17690.0 KM   1st
# 233              Ford Figo (2013)    DIESEL   78000.0 KM   1st
#
#                                  Location       Price
# 0               Mwla Palayam, Chennimalai  ₹ 2,85,000
# 1                    Thindal Malai, Erode  ₹ 8,50,000
# ...

# %%
df_final_4 = pd.concat([df_final_3,df1,df2,df3,df4,df5],ignore_index=True)
df_final_4
# Out:
#                                  Model Fuel Type     Mileage Owner  \
# 0               Tata Indigo Ecs (2010)    PETROL  65000.0 KM   2nd
# 1     Maruti Suzuki Swift Dzire (2018)    DIESEL  32000.0 KM   1st
# 2          Maruti Suzuki Ertiga (2018)    DIESEL  48000.0 KM   1st
# 3                   Hyundai I10 (2013)    PETROL  68000.0 KM   2nd
# 4                     Tata Nano (2015)    PETROL  22000.0 KM   1st
# ...                                ...       ...         ...   ...
# 4692        Maruti Suzuki Swift (2011)    DIESEL  70000.0 KM    --
# 4693            Toyota Fortuner (2009)    DIESEL  140,000 KM    --
# 4694               Renault Kwid (2021)    PETROL   4000.0 KM   1st
# 4695        Maruti Suzuki Ignis (2019)    PETROL  17690.0 KM   1st
# 4696                  Ford Figo (2013)    DIESEL  78000.0 KM   1st
#
#                               Location       Price
# 0                 Shastri Nagar, Delhi  ₹ 1,10,000
# 1     SR Nagar Colony, Tiruchirappalli  ₹ 7,90,000
# ...

# %%
df_final_4.to_csv('olx_cars_final_4.csv',index=False)
pd.read_csv('olx_cars_final_4.csv',index_col=None)
# Out:
#                                  Model Fuel Type     Mileage Owner  \
# 0               Tata Indigo Ecs (2010)    PETROL  65000.0 KM   2nd
# 1     Maruti Suzuki Swift Dzire (2018)    DIESEL  32000.0 KM   1st
# 2          Maruti Suzuki Ertiga (2018)    DIESEL  48000.0 KM   1st
# 3                   Hyundai I10 (2013)    PETROL  68000.0 KM   2nd
# 4                     Tata Nano (2015)    PETROL  22000.0 KM   1st
# ...                                ...       ...         ...   ...
# 4692        Maruti Suzuki Swift (2011)    DIESEL  70000.0 KM    --
# 4693            Toyota Fortuner (2009)    DIESEL  140,000 KM    --
# 4694               Renault Kwid (2021)    PETROL   4000.0 KM   1st
# 4695        Maruti Suzuki Ignis (2019)    PETROL  17690.0 KM   1st
# 4696                  Ford Figo (2013)    DIESEL  78000.0 KM   1st
#
#                               Location       Price
# 0                 Shastri Nagar, Delhi  ₹ 1,10,000
# 1     SR Nagar Colony, Tiruchirappalli  ₹ 7,90,000
# ...
